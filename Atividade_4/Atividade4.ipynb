# %%
# !pip install pandas
# !pip install openpyxl

import pandas as pd 
import openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.3.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.3.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
caminho = r"H:\Python\3°-Etapa\Atividade_4\CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"

# %%
tabela_populacao = pd.read_excel(caminho, header = 2)

# %%
tabela_populacao
# Out:
#       Unnamed: 0                                                 UF  COD. UF  \
# 0            NaN                                                 RO     11.0
# 1            NaN                                                 RO     11.0
# 2            NaN                                                 RO     11.0
# 3            NaN                                                 RO     11.0
# 4            NaN                                                 RO     11.0
# ...          ...                                                ...      ...
# 5569         NaN                                                 DF     53.0
# 5570         NaN                                                NaN      NaN
# 5571         NaN  Nota: Para o cálculo das taxas de crescimento ...      NaN
# 5572         NaN                                                NaN      NaN
# 5573         NaN  Fonte: IBGE. Diretoria de Pesquisas - DPE -  C...      NaN
#
# ...

# %%
tabela_populacao = tabela_populacao.iloc[ 1:5570, 1:]

# %%
tabela_populacao["diferenca"] = tabela_populacao["População Censo 2022"] - tabela_populacao["População Município 2010\n(Sinopse)"]

# %%
tabela_populacao.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO',
#        'População Município 2010\n(Sinopse)',
#        'População 2010 (Alterações de Limites até 2022)1',
#        'População Censo 2022', 'diferenca'],
#       dtype='str')

# %%
uf_populacao = (tabela_populacao.groupby("UF")[['População Município 2010\n(Sinopse)',
       'População 2010 (Alterações de Limites até 2022)1',
       'População Censo 2022', 'diferenca']]).sum().reset_index()

# %%
uf_populacao.sort_values(by='UF', ascending=True)
# Out:
#     UF  População Município 2010\n(Sinopse)  \
# 0   AC                             733559.0
# 1   AL                            3120494.0
# 2   AM                            3483985.0
# 3   AP                             669526.0
# 4   BA                           14016906.0
# 5   CE                            8452381.0
# 6   DF                            2570160.0
# 7   ES                            3514952.0
# 8   GO                            6003788.0
# 9   MA                            6574789.0
# 10  MG                           19597330.0
# 11  MS                            2449024.0
# 12  MT                            3035122.0
# 13  PA                            7581051.0
# 14  PB                            3766528.0
# 15  PE                            8796448.0
# 16  PI                            3118360.0
# 17  PR                           10444526.0
# 18  RJ                           15989929.0
# 19  RN                            3168027.0
# ...

# %%
uf_populacao.to_csv(r"H:\Python\3°-Etapa\Atividade_4\uf_populacao.csv", sep =";")

# %%
muni_populacao = (tabela_populacao.groupby("NOME DO MUNICÍPIO")[['População Município 2010\n(Sinopse)',
       'População 2010 (Alterações de Limites até 2022)1',
       'População Censo 2022', 'diferenca']]).sum().reset_index()

# %%
muni_populacao.sort_values(by='NOME DO MUNICÍPIO', ascending=True)
# Out:
#         NOME DO MUNICÍPIO  População Município 2010\n(Sinopse)  \
# 0         Abadia de Goiás                               6876.0
# 1     Abadia dos Dourados                               6704.0
# 2               Abadiânia                              15757.0
# 3              Abaetetuba                             141100.0
# 4                  Abaeté                              22690.0
# ...                   ...                                  ...
# 5291                Áurea                               3665.0
# 5292               Ângulo                               2859.0
# 5293        Érico Cardoso                              10859.0
# 5294               Óbidos                              49333.0
# 5295                 Óleo                               2673.0
#
#       População 2010 (Alterações de Limites até 2022)1  População Censo 2022  \
# 0                                               6891.0               19128.0
# ...

# %%
muni_populacao.to_csv(r"H:\Python\3°-Etapa\Atividade_4\muni_populacao.csv", sep =";")
